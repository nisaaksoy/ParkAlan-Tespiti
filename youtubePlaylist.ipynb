# %%
import yt_dlp
import os

# İndirme ve işleme yapılacak klasör
output_folder = "indirilen_gitar_sarkilari"

# Klasörü oluştur (varsa hata vermez)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# YouTube playlist veya kanalındaki tüm videoları indir ve ses dosyasını çıkart
def download_playlist_audio(playlist_url, output_folder):
    try:
        ydl_opts = {
            'format': 'bestaudio/best',
            'outtmpl': os.path.join(output_folder, '%(title)s.%(ext)s'),
            'postprocessors': [{
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'mp3',
                'preferredquality': '192',
            }],
            'noplaylist': False,  # Çalma listesi indirilmesini sağlamak için False olmalı
        }
        
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([playlist_url])
        
        print(f"Çalma listesi başarıyla indirildi ve {output_folder} klasörüne kaydedildi.")
    
    except Exception as e:
        print(f"Bir hata oluştu: {str(e)}")

# Örnek: YouTube playlist ya da kanal sayfası URL'si
playlist_url = "https://www.youtube.com/playlist?list=PL3UTZuJF_rUqbJ2OgyDP7O4129eo-ECiE"  # Çalma listesi URL'sini buraya ekle

# Playlist'teki tüm videoları indir ve MP3 formatında kaydet
download_playlist_audio(playlist_url, output_folder)
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PL3UTZuJF_rUqbJ2OgyDP7O4129eo-ECiE
# [youtube:tab] PL3UTZuJF_rUqbJ2OgyDP7O4129eo-ECiE: Downloading webpage
# [youtube:tab] PL3UTZuJF_rUqbJ2OgyDP7O4129eo-ECiE: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: gitar
# [youtube:tab] PL3UTZuJF_rUqbJ2OgyDP7O4129eo-ECiE page 1: Downloading API JSON
# [youtube:tab] Playlist gitar: Downloading 22 items of 22
# [download] Downloading item 1 of 22
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VC02wGj5gPw
# [youtube] VC02wGj5gPw: Downloading webpage
# [youtube] VC02wGj5gPw: Downloading ios player API JSON
# [youtube] VC02wGj5gPw: Downloading mweb player API JSON
# [youtube] VC02wGj5gPw: Downloading m3u8 information
# [info] VC02wGj5gPw: Downloading 1 format(s): 251
# [download] Destination: indirilen_gitar_sarkilari\JEFF BECK LIVE Cause We've Ended As Lovers.webm
# [download] 100% of    5.17MiB in 00:00:01 at 3.19MiB/s
# ...
